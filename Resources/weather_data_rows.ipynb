# %%
import pandas as pd

weather_df = pd.read_csv("weather_data.csv", delimiter=",")
html_rows = weather_df.to_html("weather_data.html", index=False)
table_data = weather_df.to_html()
print(table_data)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>% Humidity</th>
#       <th>% Cloudiness</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Manokwari</td>
#       <td>-0.8667</td>
#       <td>134.0833</td>
#       <td>299.35</td>
#       <td>75</td>
#       <td>100</td>
#       <td>1.07</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Saint Paul Harbor</td>
#       <td>57.7900</td>
#       <td>-152.4072</td>
#       <td>285.88</td>
#       <td>67</td>
#       <td>20</td>
#       <td>7.72</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bhag</td>
#       <td>29.0415</td>
#       <td>67.8239</td>
#       <td>302.17</td>
#       <td>20</td>
#       <td>0</td>
#       <td>1.91</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...
